# %%
# !pip install snakeviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 1.8 MB/s eta 0:00:001.6 MB/s eta 0:00:01
# ...

# %%
# !python -m cProfile -o profile_data train.py 2
# !snakeviz profile_data
# Out:
# wandb: Currently logged in as: 1805109 (thesis_bank_document). Use `wandb login --relogin` to force relogin
# loading annotations into memory...
# Done (t=18.62s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=4.80s)
# creating index...
# index created!
# 2024-01-20 13:20:34,827 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# loading annotations into memory...
# Done (t=8.18s)
# creating index...
# index created!
# 2024-01-20 13:20:44,154 - mmdet - INFO - load checkpoint from local path: /media/quadro/NVME/Mehrab/exps/32_quad_long_retry/epoch_64.pth
# 2024-01-20 13:20:47,938 - root - INFO - ModulatedDeformConvPack neck.deconv_layers.0.conv is upgraded to version 2.
# 2024-01-20 13:20:47,939 - root - INFO - ModulatedDeformConvPack neck.deconv_layers.2.conv is upgraded to version 2.
# 2024-01-20 13:20:47,941 - root - INFO - ModulatedDeformConvPack neck.deconv_layers.4.conv is upgraded to version 2.
# ...
